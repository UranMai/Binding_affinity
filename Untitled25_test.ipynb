# %% [markdown]
# <a href="https://colab.research.google.com/github/UranMai/Binding_affinity/blob/master/Untitled25_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install rdkit library for molecules
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# !time bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# !time conda install -q -y -c conda-forge rdkit

import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')

from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Descriptors
from rdkit.Chem import AllChem
from rdkit import DataStructs

# %%
import pandas as pd
data = pd.read_csv("data_200000.csv")
data = data[1:10000]
data = data[data.columns[1:4]]

# %%
data
# Out:
#                                                     smi  ...  score
# 0                  Nc1nc2nc(-c3ccccc3)cc(-c3ccccc3)n2n1  ...    0.0
# 1             O=C1[C@@H](N2CCc3cccc(F)c32)CCN1CC(F)(F)F  ...    1.0
# 2                   CSCc1cc(C(=O)N2CCc3[nH]ncc3C2)ccc1F  ...    0.0
# 3                  CC(=O)Nc1ccc(NC(=O)CSc2ccc(F)cc2)cc1  ...    0.0
# 4                         CC1(C)C[C@H]1C(=O)NC1CCCCCCC1  ...    0.0
# ...                                                 ...  ...    ...
# 9963   O=C(O)[C@H]1Cc2ccccc2CN1C(=O)Cc1coc(-c2ccccc2)n1  ...    1.0
# 9964         Cc1cnc(C(=O)N[C@@H](CC(=O)O)c2ccccc2Cl)cn1  ...    1.0
# 9965  Cc1ccccc1[C@H]1CN(Cc2ccc(Cl)c(F)c2)[C@H](CO)[C...  ...    0.0
# 9966  Cc1nccnc1N1C[C@H](c2cccc(F)c2F)[C@@H]2[C@H]1C1...  ...    0.0
# 9967            Nc1cc(C(=O)N2CCC(Oc3ccc(Cl)cc3)CC2)ccn1  ...    1.0
#
# [9968 rows x 4 columns]

# %%
data['mol'] = data['smi'].apply(lambda x: Chem.MolFromSmiles(x))
data = data.dropna()
data = data.reset_index(drop=True)
data.head()

# %%
data.loc[data.Score > -30, 'score'] = 0
data.loc[data.Score < -30, 'score'] = 1

# %%
data['score'].value_counts()
# Out:
# 0.0    8192
# 1.0    1776
# Name: score, dtype: int64

# %%
data
# Out:
#                                                      smi  ...  score
# 0                   Nc1nc2nc(-c3ccccc3)cc(-c3ccccc3)n2n1  ...    0.0
# 1              O=C1[C@@H](N2CCc3cccc(F)c32)CCN1CC(F)(F)F  ...    1.0
# 2                    CSCc1cc(C(=O)N2CCc3[nH]ncc3C2)ccc1F  ...    0.0
# 3                   CC(=O)Nc1ccc(NC(=O)CSc2ccc(F)cc2)cc1  ...    0.0
# 4                          CC1(C)C[C@H]1C(=O)NC1CCCCCCC1  ...    0.0
# ...                                                  ...  ...    ...
# 19937             CCn1cc(C2CCN(c3ncc(C(F)(F)F)s3)CC2)cn1  ...    0.0
# 19938  COc1ccc(-c2ccc(=O)n(CC(=O)N=c3[nH]c4ccccc4[nH]...  ...    1.0
# 19939  O=C(Cc1cccnc1)N1CCC[C@H](CNC(=O)c2ccc3c(c2)OCO...  ...    1.0
# 19940                   CN(C(=O)Cc1noc2ccccc21)c1ccccc1F  ...    0.0
# 19941       CCn1c(CC2CCN(C(=O)[C@H]3C=CCN3)CC2)nn(C)c1=O  ...    0.0
#
# [19942 rows x 4 columns]

# %%
#data['bit_vect'] = data['mol'].apply(lambda x: AllChem.GetMorganFingerprintAsBitVect(x,2,1024))

# %% [markdown]
# # tanimoto_similarity
# # 1 - is the equivalent
# # 0 - is different
#
# **calculate similarities and convert to distances by substacting from 1**
#
#
# fps[:i] - first i-1 elements
#
# **Butina clustering** with distthreshold (<0.83) divides to clusters if less then threshold
#
# If threshold less (like 0.4, default is 0.7) than the division more precise

# %% [markdown]
# Butina.ClusterData(data, nPts, distThresh, isDistData=False, distFunc=<function EuclideanDist>, reordering=False)
#
#
#
# *   clusters the data points passed in and returns the list of clusters
# *

# %%
fps = [AllChem.GetMorganFingerprintAsBitVect(x,2,1024) for x in data['mol']]

# %%
len(fps)
# Out:
# 9968

# %%
dists = []
len_fps = len(fps)
for i in range(1, len_fps):
  sims = DataStructs.BulkTanimotoSimilarity(fps[i], fps[:i]) #Tanimoto similarities(float values) between fps
  dists.extend([1-x for x in sims])

# %%
cs = Butina.ClusterData(dists, len_fps, 0.2, isDistData = True)

# %%
ml1 = data['mol'][9634]
ml2 = data['mol'][4687]
ml3 = data['mol'][9612]
ml4 = data['mol'][7462]

mols = (ml1, ml2, ml3, ml4)
Draw.MolsToGridImage(mols)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x400 at 0x7FD88B89E860>

# %%
cs
# Out:
# ((9634, 4687),
#  (9612, 7462),
#  (9608, 8373),
#  (9572, 4640),
#  (9355, 6858),
#  (9340, 9041),
#  (8766, 5468),
#  (8340, 3039),
#  (8268, 1636),
#  (7708, 6811),
#  (7598, 3669),
#  (7347, 5143),
#  (7279, 4635),
#  (7188, 3152),
#  (7166, 359),
#  (7051, 109),
#  (6768, 779),
#  (6685, 2985),
#  (6658, 1364),
#  (6408, 736),
#  (6082, 813),
#  (5790, 4289),
#  (5647, 3418),
#  (5342, 2229),
#  (3416, 3137),
#  (3173, 2069),
#  (889, 807),
#  (9967,),
#  (9966,),
#  (9965,),
#  (9964,),
#  (9963,),
#  (9962,),
#  (9961,),
#  (9960,),
#  (9959,),
#  (9958,),
#  (9957,),
#  (9956,),
#  (9955,),
#  (9954,),
#  (9953,),
#  (9952,),
#  (9951,),
#  (9950,),
#  (9949,),
#  (9948,),
#  (9947,),
#  (9946,),
#  (9945,),
#  (9944,),
#  (9943,),
#  (9942,),
#  (9941,),
#  (9940,),
#  (9939,),
#  (9938,),
#  (9937,),
#  (9936,),
#  (9935,),
#  (9934,),
#  (9933,),
#  (9932,),
#  (9931,),
#  (9930,),
#  (9929,),
#  (9928,),
#  (9927,),
#  (9926,),
#  (9925,),
#  (9924,),
#  (9923,),
#  (9922,),
#  (9921,),
#  (9920,),
#  (9919,),
#  (9918,),
#  (9917,),
#  (9916,),
#  (9915,),
#  (9914,),
#  (9913,),
#  (9912,),
#  (9911,),
#  (9910,),
#  (9909,),
#  (9908,),
#  (9907,),
#  (9906,),
#  (9905,),
#  (9904,),
#  (9903,),
#  (9902,),
#  (9901,),
#  (9900,),
#  (9899,),
#  (9898,),
#  (9897,),
#  (9896,),
#  (9895,),
#  (9894,),
#  (9893,),
#  (9892,),
#  (9891,),
#  (9890,),
#  (9889,),
#  (9888,),
#  (9887,),
#  (9886,),
#  (9885,),
#  (9884,),
#  (9883,),
#  (9882,),
#  (9881,),
#  (9880,),
#  (9879,),
#  (9878,),
#  (9877,),
#  (9876,),
#  (9875,),
#  (9874,),
#  (9873,),
#  (9872,),
#  (9871,),
#  (9870,),
#  (9869,),
#  (9868,),
#  (9867,),
#  (9866,),
#  (9068,),
#  (9067,),
#  (9066,),
#  (9065,),
#  (9064,),
#  (9063,),
#  (9062,),
#  (9061,),
#  (9060,),
#  (9059,),
#  (9058,),
#  (9057,),
#  (9056,),
#  (9055,),
#  (9054,),
#  (9053,),
#  (9052,),
#  (9051,),
#  (9050,),
#  (9049,),
#  (9048,),
#  (9047,),
#  (9046,),
#  (9045,),
#  (9044,),
#  (9043,),
#  (9042,),
#  (9040,),
#  (9039,),
#  (9038,),
#  (9037,),
#  (9036,),
#  (9035,),
#  (9034,),
#  (9033,),
#  (9032,),
#  (9031,),
#  (9030,),
#  (9029,),
#  (9028,),
#  (9027,),
#  (9026,),
#  (9025,),
#  (9024,),
#  (9023,),
#  (9022,),
#  (9021,),
#  (9020,),
#  (9019,),
#  (9018,),
#  (9017,),
#  (9016,),
#  (9015,),
#  (9014,),
#  (9013,),
#  (9012,),
#  (9011,),
#  (9010,),
#  (9009,),
#  (9008,),
#  (9007,),
#  (9006,),
#  (9005,),
#  (9004,),
#  (9003,),
#  (9002,),
#  (9001,),
#  (9000,),
#  (8999,),
#  (8998,),
#  (8997,),
#  (8996,),
#  (8995,),
#  (8994,),
#  (8993,),
#  (8992,),
#  (8991,),
#  (8990,),
#  (8989,),
#  (8988,),
#  ...)

# %%
from rdkit.ML.Cluster import Butina

# Returns a Morgan fingerprint for a molecules (data of molecules) as a bit vector of shape 1024
fps = [AllChem.GetMorganFingerprintAsBitVect(x,2,1024) for x in data['mol']] 


def Cluster_Fps(fps, cutoff=0.2):
  dists = []
  len_fps = len(fps)
  for i in range(1, len_fps):
    sims = DataStructs.BulkTanimotoSimilarity(fps[i], fps[:i]) #Tanimoto similarities(float values) between fps
    dists.extend([1-x for x in sims])

  cs = Butina.ClusterData(dists, len_fps, cutoff, isDistData = True)
  return cs


#cluster = Cluster_Fps(fps, cutoff=0.4)

# %%
cluster = Cluster_Fps(fps, cutoff=0.4)

# %%
len(cluster)
# Out:
# 18608

# %%
def Cluster_histogram(fps):
    dists=[]
    for i in range(1, len(fps)):
        sims = DataStructs.BulkTanimotoSimilarity(fps[i], fps[:i])
        dists.extend([1-x for x in sims])
    return dists

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.hist(Cluster_histogram(fps), bins=500)
plt.show()

# %%
#fps = [AllChem.GetMorganFingerprintAsBitVect(x,2,1024) for x in data['mol']]
#Fingeprints circular
#fps1 = [AllChem.GetMorganFingerprintAsBitVect(x,2,2048) for x in data['mol']]
#return ExplicitBitVector

#fps2 = [AllChem.GetMorganFingerprintAsBitVect(x,3,1024) for x in data['mol']] #more ones(1) when radius increases, more details

# %%
#clustering with cuoff=0.4
#print(len(cluster))
#print(cluster)

# %% [markdown]
# # rr

# %%
''' Different molecules
ml1 = data['mol'][21]
ml2 = data['mol'][20]
ml3 = data['mol'][19]
ml4 = data['mol'][24]

mols = (ml1, ml2, ml3, ml4)
Draw.MolsToGridImage(mols)
'''
# Out:
# " Different molecules\nml1 = data['mol'][21]\nml2 = data['mol'][20]\nml3 = data['mol'][19]\nml4 = data['mol'][24]\n\nmols = (ml1, ml2, ml3, ml4)\nDraw.MolsToGridImage(mols)\n"

# %% [markdown]
# # New Sectionrr

# %%
'''
  make_data function create train/valid/test dataframes

  input: cluster after Clustering represent as tuple of tuples of elements
         data - our Dataframe of smiles and scores
  output: dataframes

'''
def make_data(cluster, data):
  datum = data.copy()
  data_list = list(sum(cluster, ()))
  length_train = int(len(data_list)*.8)
  length_valid = int(len(data_list)*.9)
  #length_test = int(len(data_list)*.1)
  #length_test = len(data) - length_train - length_valid

  data_train = data_list[:length_train]
  data_valid = data_list[length_train:length_valid]
  data_test = data_list[length_valid:]

  dframe_train = pd.DataFrame()
  dframe_valid = pd.DataFrame() #one parameter in it, column=['smi','Score']
  dframe_test  = pd.DataFrame()

  
  for id, value in enumerate(data_train):
    dframe_train = dframe_train.append(datum.iloc[[value], [0,1,2,3]], ignore_index=True)

  for value in data_valid:
    dframe_valid = dframe_valid.append(datum.iloc[[value], [0,1,2,3]], ignore_index=True)

  for value in data_test:
    dframe_test = dframe_test.append(datum.iloc[[value], [0,1,2,3]], ignore_index=True)
  
  return dframe_train, dframe_valid, dframe_test

# %%
split = make_data(cluster, data)

# %%
split_train = split[0]
split_train.to_csv('train_data.csv')

# %%
split_valid = split[1]
split_valid.to_csv('valid_data.csv')

# %%
split_test = split[2]
split_test.to_csv('test_data.csv')

# %%
split
# Out:
# (                                                     smi  ...  score
#  0        CCOC(=O)C1=C(C)N=C2SCCC(=O)N2[C@H]1c1ccc(OC)cc1  ...    0.0
#  1         CCOC(=O)C1=C(C)N=C2SCC(=O)N2[C@@H]1c1ccc(F)cc1  ...    0.0
#  2      CC1=C(C(=O)OCC(C)C)[C@@H](c2ccc(F)cc2)N2C(=O)C...  ...    0.0
#  3       COC(=O)C1=C(C)N=C2SCCC(=O)N2[C@H]1c1cc(OC)ccc1OC  ...    0.0
#  4      CCOc1ccc([C@@H]2C(C(=O)OC(C)C)=C(C)N=C3SCCC(=O...  ...    0.0
#  ...                                                  ...  ...    ...
#  15948                   COc1ccc(Cn2ncnc2-c2sc(C)nc2C)cc1  ...    0.0
#  15949      Cc1nn(C)cc1[C@@H](C)NC(=O)C1(c2ccccc2F)CCOCC1  ...    0.0
#  15950      O=C(COc1ccc2nc3n(c(=O)c2c1)CCC3)Nc1ccc(Cl)cc1  ...    1.0
#  15951  Cc1ccc(CN2CCN(C(=O)[C@@H]3[C@H]4C=C[C@@H](C4)[...  ...    0.0
#  15952     CCn1ncnc1[C@H](C)NC(=O)c1cccc(-c2cncc(OC)c2)c1  ...    0.0
#
#  [15953 rows x 4 columns],
#                                                     smi  ...  score
#  0                  O=S(=O)(NCc1nnc2c(O)nccn12)c1ccccc1  ...    1.0
#  1      CC(=O)N1C[C@@H](c2nnc(-c3ccncc3)o2)C2(C1)CCOCC2  ...    0.0
#  2         CC(C)c1cc(C(=O)N2CCC[C@H](C)C2)nc(N2CCCC2)n1  ...    0.0
#  3          Cc1noc(C)c1CN1CCN(CCO[C@H]2CCCC[C@@H]2C)CC1  ...    0.0
#  4              Cc1nc(CN2CCC(C(=O)NCc3c(C)noc3C)CC2)cs1  ...    0.0
#  ...                                                ...  ...    ...
#  1989          CC[C@@H](C)NC(=O)N[C@H](C)c1ccc2ccccc2c1  ...    0.0
#  1990         Cc1ccc(N(C)C(=O)CC2CC2)cc1N(C)C(=O)CC1CC1  ...    0.0
#  1991                  CN(CCCO)C1CCN(c2ncc(Cl)cc2Cl)CC1  ...    0.0
#  1992         CC(C)(C)OC[C@@H](O)CN(Cc1ccccc1)Cc1ccccc1  ...    0.0
#  1993  COc1ccc([C@H](C)NC(=O)C(=O)Nc2ccc(C)cc2C)c(OC)c1  ...    1.0
#
#  [1994 rows x 4 columns],
#                                                      smi  ...  score
#  0        Cn1cc(C(=O)NC[C@](C)(O)c2ccc(-c3ccccc3)cc2)nn1  ...    1.0
#  1              CCCc1noc(CCCC(=O)N2CCN(c3cnn(C)c3)CC2)n1  ...    0.0
#  2                  COCc1c(Cl)cccc1NC(=O)NCC[C@H]1CCCCO1  ...    0.0
#  3                O[C@H](COCc1ccccc1)CN1CCN(c2ncccn2)CC1  ...    0.0
#  4     Cc1cccc(Cn2nc(CC(N)=O)nc2-c2ccc3c(c2)NC(=O)CN3)c1  ...    1.0
#  ...                                                 ...  ...    ...
#  1990                      CC1(C)C[C@H]1C(=O)NC1CCCCCCC1  ...    0.0
#  1991               CC(=O)Nc1ccc(NC(=O)CSc2ccc(F)cc2)cc1  ...    0.0
#  1992                CSCc1cc(C(=O)N2CCc3[nH]ncc3C2)ccc1F  ...    0.0
#  1993          O=C1[C@@H](N2CCc3cccc(F)c32)CCN1CC(F)(F)F  ...    1.0
#  1994               Nc1nc2nc(-c3ccccc3)cc(-c3ccccc3)n2n1  ...    0.0
#
#  [1995 rows x 4 columns])

# %%
'''
length = int(len(cluster) *0.8)
print(length)

ids = []
for i in range(length):
  ids.append(cluster[i])
print(ids)
'''

'''
ml1 = data['mol'][9611]
ml2 = data['mol'][7461]
mols = (ml1, ml2)
Draw.MolsToGridImage(mols)
'''
# Out:
# "\nml1 = data['mol'][9611]\nml2 = data['mol'][7461]\nmols = (ml1, ml2)\nDraw.MolsToGridImage(mols)\n"

# %%
# split_data = make_data(cluster=cluster, data=data)
# split_data[0] - train
# split_data[1] - valid
# split_data[2] - test

# %% [markdown]
# # Scaffold splitting

# %%
data
# Out:
#                                                      smi  ...  score
# 0                   Nc1nc2nc(-c3ccccc3)cc(-c3ccccc3)n2n1  ...    0.0
# 1              O=C1[C@@H](N2CCc3cccc(F)c32)CCN1CC(F)(F)F  ...    1.0
# 2                    CSCc1cc(C(=O)N2CCc3[nH]ncc3C2)ccc1F  ...    0.0
# 3                   CC(=O)Nc1ccc(NC(=O)CSc2ccc(F)cc2)cc1  ...    0.0
# 4                          CC1(C)C[C@H]1C(=O)NC1CCCCCCC1  ...    0.0
# ...                                                  ...  ...    ...
# 19937             CCn1cc(C2CCN(c3ncc(C(F)(F)F)s3)CC2)cn1  ...    0.0
# 19938  COc1ccc(-c2ccc(=O)n(CC(=O)N=c3[nH]c4ccccc4[nH]...  ...    1.0
# 19939  O=C(Cc1cccnc1)N1CCC[C@H](CNC(=O)c2ccc3c(c2)OCO...  ...    1.0
# 19940                   CN(C(=O)Cc1noc2ccccc21)c1ccccc1F  ...    0.0
# 19941       CCn1c(CC2CCN(C(=O)[C@H]3C=CCN3)CC2)nn(C)c1=O  ...    0.0
#
# [19942 rows x 4 columns]

# %%
#Compute Bemis_Murcko scaffolds that contain ring systems with linker atoms
from rdkit.Chem.Scaffolds import MurckoScaffold
''' 
  input: smiles string
  return: scaffold structure of molecule
'''

def generate_scaffold(mol):
    mol = Chem.MolFromSmiles(mol)
    scaffold = MurckoScaffold.MurckoScaffoldSmiles(mol=mol, includeChirality=False)
    return scaffold
'''
def scaffold_to_smiles(mols, use_indices: bool = False):
    scaffolds = list()
    for i, mol in tqdm(enumerate(mols), total=len(mols)):
        scaffold = generate_scaffold(mol)
        if use_indices:
            scaffolds[scaffold].add(i)
        else:
            scaffolds[scaffold].add(mol)

    return scaffolds
'''

# %%
def train_valid_test_split(data,
          frac_train=.8,
          frac_valid=.1,
          frac_test=.1):
    """
        Splits internal compounds into train/validation/test by scaffold.
        Return the ids 
    """
    
    scaffolds = {}
    for ind, smiles in enumerate(data.smi):
      scaffold = generate_scaffold(smiles)
      if scaffold not in scaffolds:
        scaffolds[scaffold] = [ind]
      else:
        scaffolds[scaffold].append(ind)

    # Sort from largest to smallest scaffold sets (with more same scaffolds,
    scaffolds = {key: sorted(value) for key, value in scaffolds.items()}
    scaffold_sets = [
        scaffold_set
        for (scaffold, scaffold_set) in sorted(
            scaffolds.items(), key=lambda x: (len(x[1]), x[1][0]), reverse=True)
    ]

    train_cutoff = frac_train * len(data)
    valid_cutoff = (frac_train + frac_valid) * len(data)
    train_inds, valid_inds, test_inds = [], [], []
   
    for scaffold_set in scaffold_sets:
      if len(train_inds) + len(scaffold_set) > train_cutoff:
        if len(train_inds) + len(valid_inds) + len(scaffold_set) > valid_cutoff:
          test_inds += scaffold_set
        else:
          valid_inds += scaffold_set
      else:
        train_inds += scaffold_set

    return train_inds, valid_inds, test_inds

# %%
train = train_valid_test_split(data)[0]
valid = train_valid_test_split(data)[1]
test = train_valid_test_split(data)[2]

# %%
train

# %%
def Splitting_DataFrame(data,
                        train_inds,
                        valid_inds,
                        test_inds):
  
  datum = data.copy()
  #data_list = list(sum(cluster, ()))
  #length_train = int(len(data_list)*.8)
  #length_valid = int(len(data_list)*.9)
  #length_test = int(len(data_list)*.1)
  #length_test = len(data) - length_train - length_valid

  #data_train = data_list[:length_train]
  #data_valid = data_list[length_train:length_valid]
  #data_test = data_list[length_valid:]

  dframe_train = pd.DataFrame()
  dframe_valid = pd.DataFrame() #one parameter in it, column=['smi','Score']
  dframe_test  = pd.DataFrame()

  
  for id, value in enumerate(train_inds):
    dframe_train = dframe_train.append(datum.iloc[[value], [0,1,2]], ignore_index=True)

  for value in valid_inds:
    dframe_valid = dframe_valid.append(datum.iloc[[value], [0,1,2]], ignore_index=True)

  for value in test_inds:
    dframe_test = dframe_test.append(datum.iloc[[value], [0,1,2]], ignore_index=True)
  
  return dframe_train, dframe_valid, dframe_test

# %%
Splitting_DataFrame(data, train, valid, test)
# Out:
# (                                                    smi  ...                                               mol
#  0                       COc1ccc(N)cc1NC(=O)c1cccc(Cl)c1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd745258c10>
#  1                  COc1c(Cl)cc(C(=O)O)cc1NC(=O)c1ccccc1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd745257ad0>
#  2     Cc1cc(C)c(NC(=O)c2ccc(Cl)c(S(=O)(=O)N(C)C)c2)c...  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd74525f760>
#  3                COc1ccc(NC(=O)c2ccc(CNC(C)(C)C)cc2)cc1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd74525fbc0>
#  4     CCS(=O)(=O)Nc1ccc(C(=O)Nc2cccc([N+](=O)[O-])c2...  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd745262800>
#  ...                                                 ...  ...                                               ...
#  7968                       Cc1c(I)c(-c2ccncc2)nn1CC(C)C  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd745278030>
#  7969        Cc1cc(Br)ccc1Nc1cc(C2CC2)[nH]c(=NCC(=O)O)n1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd74527cf80>
#  7970          O=[N+]([O-])c1cccnc1NCc1ccc(Oc2ccccc2)nc1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd74527cf30>
#  7971   CCNc1nc(C)c(C(=O)N2CCC[C@@]3(C)[C@@H]2CCCCN3C)s1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd74527cee0>
#  7972               COc1ccc(OC)c(CN(CCN(C)C)Cc2ccncc2)c1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd74527ce90>
#
#  [7973 rows x 3 columns],
#                                                     smi  ...                                               mol
#  0     Cc1ccc(-c2nnc(O)c3c2[C@@H](c2ccco2)n2nnnc2N3)cc1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd74527ce40>
#  1           Cc1nc([C@H]2CCCN(C(=O)c3cncs3)C2)cc2cncn21  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd74527cdf0>
#  2            O=C(NC1CCCCCC1)C1CCN(c2cncnc2N2CCCCC2)CC1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd74527cda0>
#  3      O=C(Cc1c[nH]c2ccccc12)N1CCC[C@H](Oc2ccncc2Cl)C1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd74527cd50>
#  4    COc1ccc([C@H]2CCCN2C(=O)[C@@H]2CC(=O)N(C3CC3)C...  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd74527cd00>
#  ..                                                 ...  ...                                               ...
#  992  C/C=C/C1=C(C(=O)O)N2C(=O)[C@H](NC(=O)[C@@H](N)...  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd745259c60>
#  993  C[C@@H]1CN(C(=O)C(=O)Nc2cc3c(cc2F)NC(=O)CC3)[C...  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd745259c10>
#  994            Nn1c(SCC(=O)N2CCc3ccccc3C2)nnc1C1CCCCC1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd745259bc0>
#  995      c1ccc(CN2CC[C@]3(C[C@@H](Oc4ccccn4)CO3)C2)nc1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd745259b20>
#  996         COc1cc(Cl)c(C)cc1NC(=O)C[C@H]1CCCCN(C)C1=O  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd745259a80>
#
#  [997 rows x 3 columns],
#                                                     smi  ...                                               mol
#  0    C[C@@H](NC(=O)CN1C(=O)NC2(CCCC2)C1=O)c1cccc2cc...  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd745259a30>
#  1    C[C@@H](C(N)=O)N1CCC(C(=O)Nc2ccc(-c3nc4ccccc4[...  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd7452599e0>
#  2                O=C(CSC1CCCC1)N1CCC(N2C(=O)CNC2=O)CC1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd745259990>
#  3    CS(=O)(=O)N[C@@H]1CN(C(=O)C2(c3ccccc3F)CC2)C[C...  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd745259940>
#  4           O=C(C1CCOCC1)N1CCc2ncnc([C@@H]3CCOC3)c2CC1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd7452598f0>
#  ..                                                 ...  ...                                               ...
#  992                 CCOC(=O)CSc1nnc(NC(=O)Nc2ccccc2)s1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd745493030>
#  993      COc1ccc(N=c2cc(C3CC3)[nH]c(=NC3CC3)[nH]2)cc1F  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd7454938a0>
#  994              CC(=O)c1ccc(NC(=O)COC(=O)Cc2ccsc2)cc1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd745456210>
#  995                      CC1(C)C[C@H]1C(=O)NC1CCCCCCC1  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd745491df0>
#  996          O=C1[C@@H](N2CCc3cccc(F)c32)CCN1CC(F)(F)F  ...  <rdkit.Chem.rdchem.Mol object at 0x7fd9078a8c60>
#
#  [997 rows x 3 columns])
